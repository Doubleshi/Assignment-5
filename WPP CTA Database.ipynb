# %%
import pandas as pd

# %%
import matplotlib
# %matplotlib inline

# %%
path = 'WPP_CTA_Q.csv'
CTA_data = pd.read_csv(path)

# %%
CTA_data
# Out:
#                          时间戳记 What is your name  \
# 0   2022/11/16 1:47:27 下午 GMT              Jana
# 1   2022/11/16 1:57:43 下午 GMT             Rocio
# 2   2022/11/16 2:01:27 下午 GMT             Tilly
# 3   2022/11/16 2:04:03 下午 GMT              Jade
# 4   2022/11/16 2:12:31 下午 GMT          Jiaze Li
# 5   2022/11/16 2:22:48 下午 GMT              Dara
# 6   2022/11/16 5:39:48 下午 GMT               Wen
# 7   2022/11/16 8:32:25 下午 GMT            Adele
# 8   2022/11/17 1:43:31 下午 GMT           jasmine
# 9   2022/11/17 1:58:37 下午 GMT              Beth
# 10  2022/11/17 2:28:33 下午 GMT          Ning Wei
# 11  2022/11/18 2:18:18 下午 GMT               kat
# 12  2022/11/18 4:13:44 下午 GMT          Precious
#
#    Do you believe sexual fluidity?   What is your spirit drug?  \
# 0                              Yes                       Music
# 1                              Yes       Book;Music;Meditation
# 2                              Yes                       Music
# ...

# %%
CTA_data.head()
# Out:
#                         时间戳记 What is your name  \
# 0  2022/11/16 1:47:27 下午 GMT              Jana
# 1  2022/11/16 1:57:43 下午 GMT             Rocio
# 2  2022/11/16 2:01:27 下午 GMT             Tilly
# 3  2022/11/16 2:04:03 下午 GMT              Jade
# 4  2022/11/16 2:12:31 下午 GMT          Jiaze Li
#
#   Do you believe sexual fluidity?   What is your spirit drug?  \
# 0                             Yes                       Music
# 1                             Yes       Book;Music;Meditation
# 2                             Yes                       Music
# 3                             Yes                       Music
# 4                              No  Cigarette;Book;Movie;Music
#
#   The recent movie name you have watch  \
# 0                           The Circle
# 1                              Cruella
# 2    Everything Everywhere All at Once
# 3                         Pulp Fiction
# 4                     The darkest hour
#
#   How many pets you want to have in your life?  \
# ...

# %%
CTA_data[8:]
# Out:
#                          时间戳记 What is your name  \
# 8   2022/11/17 1:43:31 下午 GMT           jasmine
# 9   2022/11/17 1:58:37 下午 GMT              Beth
# 10  2022/11/17 2:28:33 下午 GMT          Ning Wei
# 11  2022/11/18 2:18:18 下午 GMT               kat
# 12  2022/11/18 4:13:44 下午 GMT          Precious
#
#    Do you believe sexual fluidity? What is your spirit drug?  \
# 8                              Yes                   Alcohol
# 9                              Yes                 Cigarette
# 10                             Yes                   Alcohol
# 11                             Yes                      Book
# 12                              No                   Alcohol
#
#    The recent movie name you have watch  \
# 8          the killing of a sacred deer
# 9                Repo the genetic opera
# 10                         Untouchable
# 11                             clueless
# 12                              wakanda
#
#    How many pets you want to have in your life?  \
# ...

# %%
CTA_data.columns[1:7]
# Out:
# Index(['What is your name', 'Do you believe sexual fluidity?',
#        'What is your spirit drug?', 'The recent movie name you have watch',
#        'How many pets you want to have in your life?',
#        'Where is your dream wedding place?'],
#       dtype='object')

# %%
# I tried to use data[]/rename/sign value to change the column into a short name, but failed
CTA_data.rename(columns={"Do you believe sexual fluidity?":"sexual fluidity"})
sexual_fluidity = 'Do you believe sexual fluidity?'
# Out:
#                          时间戳记 What is your name sexual fluidity  \
# 0   2022/11/16 1:47:27 下午 GMT              Jana             Yes
# 1   2022/11/16 1:57:43 下午 GMT             Rocio             Yes
# 2   2022/11/16 2:01:27 下午 GMT             Tilly             Yes
# 3   2022/11/16 2:04:03 下午 GMT              Jade             Yes
# 4   2022/11/16 2:12:31 下午 GMT          Jiaze Li              No
# 5   2022/11/16 2:22:48 下午 GMT              Dara             Yes
# 6   2022/11/16 5:39:48 下午 GMT               Wen             Yes
# 7   2022/11/16 8:32:25 下午 GMT            Adele               No
# 8   2022/11/17 1:43:31 下午 GMT           jasmine             Yes
# 9   2022/11/17 1:58:37 下午 GMT              Beth             Yes
# 10  2022/11/17 2:28:33 下午 GMT          Ning Wei             Yes
# 11  2022/11/18 2:18:18 下午 GMT               kat             Yes
# 12  2022/11/18 4:13:44 下午 GMT          Precious              No
#
# ...

# %%
SF_choice = CTA_data['Do you believe sexual fluidity?']
SF_choice
# Out:
# 0     Yes
# 1     Yes
# 2     Yes
# 3     Yes
# 4      No
# 5     Yes
# 6     Yes
# 7      No
# 8     Yes
# 9     Yes
# 10    Yes
# 11    Yes
# 12     No
# Name: Do you believe sexual fluidity?, dtype: object

# %%
WP_choice = CTA_data['Where is your dream wedding place?']
WP_choice
# Out:
# 0                        Palace
# 1                        Island
# 2                          Moon
# 3                          Moon
# 4                          Moon
# 5                        Island
# 6                        Island
# 7                          Moon
# 8                        Island
# 9     Don't want to get married
# 10                       Island
# 11          industrial building
# 12                        beach
# Name: Where is your dream wedding place?, dtype: object

# %%
WP_choice.unique()
# Out:
# array(['Palace', 'Island', 'Moon', "Don't want to get married",
#        'industrial building', 'beach'], dtype=object)

# %%
from collections import Counter
desired_marryplaces = Counter(WP_choice).most_common(3)
print(desired_marryplaces)
# Out:
# [('Island', 5), ('Moon', 4), ('Palace', 1)]

# %%
believe_sexual_fluity1 = CTA_data [[x for x in CTA_data['Where is your dream wedding place?'] == 'Moon']]
believe_sexual_fluity1
# Out:
#                         时间戳记 What is your name  \
# 2  2022/11/16 2:01:27 下午 GMT             Tilly
# 3  2022/11/16 2:04:03 下午 GMT              Jade
# 4  2022/11/16 2:12:31 下午 GMT          Jiaze Li
# 7  2022/11/16 8:32:25 下午 GMT            Adele
#
#   Do you believe sexual fluidity?   What is your spirit drug?  \
# 2                             Yes                       Music
# 3                             Yes                       Music
# 4                              No  Cigarette;Book;Movie;Music
# 7                              No                     Alcohol
#
#   The recent movie name you have watch  \
# 2    Everything Everywhere All at Once
# 3                         Pulp Fiction
# 4                     The darkest hour
# 7                         Alter carbon
#
#   How many pets you want to have in your life?  \
# 2                                            3
# 3                                            0
# 4                                            1
# ...

# %%
believe_sexual_fluity2 = CTA_data [[x for x in CTA_data['Where is your dream wedding place?'] == 'Island']]
believe_sexual_fluity2
# Out:
#                          时间戳记 What is your name  \
# 1   2022/11/16 1:57:43 下午 GMT             Rocio
# 5   2022/11/16 2:22:48 下午 GMT              Dara
# 6   2022/11/16 5:39:48 下午 GMT               Wen
# 8   2022/11/17 1:43:31 下午 GMT           jasmine
# 10  2022/11/17 2:28:33 下午 GMT          Ning Wei
#
#    Do you believe sexual fluidity? What is your spirit drug?  \
# 1                              Yes     Book;Music;Meditation
# 5                              Yes                     Music
# 6                              Yes        Movie;Music;Sports
# 8                              Yes                   Alcohol
# 10                             Yes                   Alcohol
#
#    The recent movie name you have watch  \
# 1                               Cruella
# 5                                  Sing
# 6              The Billion Dollars Code
# 8          the killing of a sacred deer
# 10                         Untouchable
#
#    How many pets you want to have in your life?  \
# ...

# %%
believe_sexual_fluity3 = CTA_data [[x for x in CTA_data['Where is your dream wedding place?'] == 'Palace']]
believe_sexual_fluity3
# Out:
#                         时间戳记 What is your name  \
# 0  2022/11/16 1:47:27 下午 GMT              Jana
#
#   Do you believe sexual fluidity? What is your spirit drug?  \
# 0                             Yes                     Music
#
#   The recent movie name you have watch  \
# 0                           The Circle
#
#   How many pets you want to have in your life?  \
# 0                                            1
#
#   Where is your dream wedding place? Unnamed: 7
# 0                             Palace         No

# %%
SD_choice = CTA_data['What is your spirit drug?']
SD_choice
# Out:
# 0                          Music
# 1          Book;Music;Meditation
# 2                          Music
# 3                          Music
# 4     Cigarette;Book;Movie;Music
# 5                          Music
# 6             Movie;Music;Sports
# 7                        Alcohol
# 8                        Alcohol
# 9                      Cigarette
# 10                       Alcohol
# 11                          Book
# 12                       Alcohol
# Name: What is your spirit drug?, dtype: object

# %%
SD_choice.unique()
# Out:
# array(['Music', 'Book;Music;Meditation', 'Cigarette;Book;Movie;Music',
#        'Movie;Music;Sports', 'Alcohol', 'Cigarette', 'Book'], dtype=object)

# %%
from collections import Counter
Popular_SD = Counter(SD_choice).most_common(3)
print(Popular_SD)
# Out:
# [('Music', 4), ('Alcohol', 4), ('Book;Music;Meditation', 1)]

# %%
CTA_data.loc[CTA_data ['What is your spirit drug?'] == 'Music' ]
# Out:
#                         时间戳记 What is your name  \
# 0  2022/11/16 1:47:27 下午 GMT              Jana
# 2  2022/11/16 2:01:27 下午 GMT             Tilly
# 3  2022/11/16 2:04:03 下午 GMT              Jade
# 5  2022/11/16 2:22:48 下午 GMT              Dara
#
#   Do you believe sexual fluidity? What is your spirit drug?  \
# 0                             Yes                     Music
# 2                             Yes                     Music
# 3                             Yes                     Music
# 5                             Yes                     Music
#
#   The recent movie name you have watch  \
# 0                           The Circle
# 2    Everything Everywhere All at Once
# 3                         Pulp Fiction
# 5                                 Sing
#
#   How many pets you want to have in your life?  \
# 0                                            1
# 2                                            3
# 3                                            0
# ...

# %%
# what if I want to acount the multiple choices answer as the same single answer. eg. 'Music','Book;Music;Meditation', Music is a same answer

CTA_data.loc[CTA_data ['What is your spirit drug?'] == 'Movie' ]
# Out:
# Empty DataFrame
# Columns: [时间戳记, What is your name, Do you believe sexual fluidity?, What is your spirit drug?, The recent movie name you have watch, How many pets you want to have in your life?, Where is your dream wedding place?, Unnamed: 7]
# Index: []

# %%
CTA_data.loc[CTA_data ['What is your spirit drug?'] == 'Alcohol' ]
# Out:
#                          时间戳记 What is your name  \
# 7   2022/11/16 8:32:25 下午 GMT            Adele
# 8   2022/11/17 1:43:31 下午 GMT           jasmine
# 10  2022/11/17 2:28:33 下午 GMT          Ning Wei
# 12  2022/11/18 4:13:44 下午 GMT          Precious
#
#    Do you believe sexual fluidity? What is your spirit drug?  \
# 7                               No                   Alcohol
# 8                              Yes                   Alcohol
# 10                             Yes                   Alcohol
# 12                              No                   Alcohol
#
#    The recent movie name you have watch  \
# 7                          Alter carbon
# 8          the killing of a sacred deer
# 10                         Untouchable
# 12                              wakanda
#
#    How many pets you want to have in your life?  \
# 7                                             2
# 8                           as many as possible
# 10                                            4
# ...

# %%
CTA_data.loc[CTA_data ['What is your spirit drug?'] == 'Cigarette' ]
# Out:
#                         时间戳记 What is your name  \
# 9  2022/11/17 1:58:37 下午 GMT              Beth
#
#   Do you believe sexual fluidity? What is your spirit drug?  \
# 9                             Yes                 Cigarette
#
#   The recent movie name you have watch  \
# 9               Repo the genetic opera
#
#   How many pets you want to have in your life?  \
# 9                                            1
#
#   Where is your dream wedding place? Unnamed: 7
# 9          Don't want to get married         No

# %%
CTA_data.loc[CTA_data['What is your name'] == 'Jiaze Li']
# Out:
#                         时间戳记 What is your name  \
# 4  2022/11/16 2:12:31 下午 GMT          Jiaze Li
#
#   Do you believe sexual fluidity?   What is your spirit drug?  \
# 4                              No  Cigarette;Book;Movie;Music
#
#   The recent movie name you have watch  \
# 4                     The darkest hour
#
#   How many pets you want to have in your life?  \
# 4                                            1
#
#   Where is your dream wedding place?                 Unnamed: 7
# 4                               Moon  wooden god (I created it)

# %%
Love_pet_person = CTA_data.loc[CTA_data['How many pets you want to have in your life?'] == CTA_data['How many pets you want to have in your life?'].max(), 'What is your name']
print(Love_pet_person)
print(Love_pet_person.item())
# Out:
# 8    jasmine
# Name: What is your name, dtype: object
# jasmine
